# %% [markdown]
# <a href="https://colab.research.google.com/github/BayanSafaeian/BayanSafaeian/blob/main/Graphing_excerize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
video_game_data = pd.read_excel('/content/drive/MyDrive/Coding Dojo/Coding dojo data/Data.xlsx')

video_game_data.head(8)
# Out:
#                 Nintendo Switch Platform  ... 3/2020
# 0         Nintendo Switch hardware/Japan  ...    521
# 1  Nintendo Switch hardware/The Americas  ...    811
# 2        Nintendo Switch hardware/Europe  ...    534
# 3         Nintendo Switch hardware/Other  ...    237
# 4         Nintendo Switch software/Japan  ...   3256
# 5  Nintendo Switch software/The Americas  ...   7428
# 6        Nintendo Switch software/Europe  ...   5017
# 7         Nintendo Switch software/Other  ...   1171
#
# [8 rows x 6 columns]

# %%
video_game_data.plot.barh(x= 'Nintendo Switch Platform', figsize = (20,20));
